# %%
import pandas as pd

# %%
path  = r'..\data\processed\cleaned.parquet'

# %%
df = pd.read_parquet(path)

# %%
df.columns
# Out:
# Index(['fund_cnpj', 'report_date', 'total_value', 'quota_value',
#        'net_asset_value', 'daily_inflow', 'daily_redemptions',
#        'num_shareholders'],
#       dtype='object')

# %%
df = df.sort_values('report_date').reset_index(drop=True)

# %%
df.head(), df.shape
# Out:
# (            fund_cnpj report_date   total_value  quota_value  net_asset_value  \
#  0  00.068.305/0001-35  2025-01-02  3.807114e+07    38.725315     3.806176e+07
#  1  42.776.707/0001-34  2025-01-02  2.393748e+07     1.351702     2.406793e+07
#  2  42.774.769/0001-07  2025-01-02  9.074660e+08     1.124264     9.085936e+08
#  3  09.087.301/0001-79  2025-01-02  1.404225e+08     4.053659     1.404109e+08
#  4  42.774.627/0001-40  2025-01-02  1.328108e+09     1.428844     1.325868e+09
#
#     daily_inflow  daily_redemptions  num_shareholders
#  0          0.00             141.07            5813.0
#  1       7424.84          114907.07            3001.0
#  2    8080779.52               0.00              86.0
#  3       3000.00               0.00             113.0
#  4    2694341.52         1636211.82           24039.0  ,
#  (1562619, 8))

# %%
groupy_by_cnpj = df.groupby('fund_cnpj')

# %%
df['return'] = groupy_by_cnpj['quota_value'].pct_change()
df['total_value_by_net_asset_value'] = df['total_value'] / df['net_asset_value']

# %%
len(df['fund_cnpj'].unique())
# Out:
# 7875

# %%
df[df['total_value'] < 0].sort_values('fund_cnpj')
# Out:
#                   fund_cnpj report_date  total_value  quota_value  \
# 878192   19.391.026/0001-36  2025-08-01 -14559796.26    -0.324561
# 897770   26.587.503/0001-07  2025-08-06   -267624.42     2.092986
# 889721   26.587.503/0001-07  2025-08-05   -331013.51     2.072788
# 2746     32.222.977/0001-40  2025-01-02  -7910862.73  -273.353853
# 952228   32.222.977/0001-40  2025-08-18  -7844209.22  -269.927105
# ...                     ...         ...          ...          ...
# 1482807  62.948.191/0001-75  2025-12-05    -89768.18   -18.527463
# 1480086  62.948.191/0001-75  2025-12-04    -87936.16   -18.110170
# 1471892  62.948.191/0001-75  2025-12-03    -86104.14   -17.692877
# 1453410  62.948.191/0001-75  2025-12-01    -82440.10   -16.858291
# 1324662  62.948.191/0001-75  2025-11-04     -9153.12    -2.748661
#
#          net_asset_value  daily_inflow  daily_redemptions  num_shareholders  \
# 878192      -24405465.16           0.0                0.0              25.0
# ...

# %%
df.describe()
# Out:
# c:\Users\ferre\OneDrive\Área de Trabalho\new projects\.venv\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\ferre\OneDrive\Área de Trabalho\new projects\.venv\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                          report_date   total_value   quota_value  \
# count                        1562619  1.562619e+06  1.562619e+06
# mean   2025-07-05 04:30:47.989817344  8.403766e+08  4.428128e+04
# min              2025-01-02 00:00:00 -1.088784e+08 -1.562452e+03
# 25%              2025-04-07 00:00:00  1.699758e+07  1.338391e+00
# 50%              2025-07-11 00:00:00  6.593944e+07  2.495391e+00
# 75%              2025-10-02 00:00:00  2.585215e+08  2.151883e+01
# max              2025-12-22 00:00:00  2.124699e+11  6.716873e+10
# ...

# %%
bad_cnpjs = df.loc[df["num_shareholders"] < 15, "fund_cnpj"].unique()
filtered_df = df[~df["fund_cnpj"].isin(bad_cnpjs)]

# %%
filtered_df['fund_cnpj'].unique().shape
# Out:
# (5677,)

# %%
df.describe()
# Out:
# c:\Users\ferre\OneDrive\Área de Trabalho\new projects\.venv\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\ferre\OneDrive\Área de Trabalho\new projects\.venv\lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                          report_date   total_value   quota_value  \
# count                        1562619  1.562619e+06  1.562619e+06
# mean   2025-07-05 04:30:47.989817344  8.403766e+08  4.428128e+04
# min              2025-01-02 00:00:00 -1.088784e+08 -1.562452e+03
# 25%              2025-04-07 00:00:00  1.699758e+07  1.338391e+00
# 50%              2025-07-11 00:00:00  6.593944e+07  2.495391e+00
# 75%              2025-10-02 00:00:00  2.585215e+08  2.151883e+01
# max              2025-12-22 00:00:00  2.124699e+11  6.716873e+10
# ...
